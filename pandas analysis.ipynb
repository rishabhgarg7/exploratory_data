# %%
import pandas as pd

# %%
df=pd.read_csv("food_info.csv")
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.head()
df.index
# Out:
# RangeIndex(start=0, stop=8618, step=1)

# %%
df.iloc[[23,33]]
# Out:
#     NDB_No             Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 23    1024      CHEESE LIMBURGER      48.42         327        20.05
# 33    1034  CHEESE PORT DE SALUT      45.45         352        23.78
#
#     Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 23          27.25     3.79            0.49           0.0           0.49
# 33          28.20     2.00            0.57           0.0           0.57
#
#          ...        Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  \
# 23       ...          1155.0      340.0        0.23        0.5      20.0
# 33       ...          1092.0      315.0        0.24        0.5      21.0
#
#     Vit_K_(mcg)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  Cholestrl_(mg)
# 23          2.3      16.746        8.606        0.495            90.0
# 33          2.4      16.691        9.338        0.729           123.0
#
# [2 rows x 36 columns]

# %%
df.describe()
# Out:
#              NDB_No    Water_(g)   Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  \
# count   8618.000000  8612.000000  8618.000000   8618.00000    8618.000000
# mean   15467.757368    54.163710   226.438617     11.52391      10.647024
# std     9221.428766    30.648283   169.388910     10.55059      15.866353
# min     1001.000000     0.000000     0.000000      0.00000       0.000000
# 25%     8695.250000    30.087500    93.000000      2.47000       0.992500
# 50%    14273.000000    63.265000   191.000000      8.28500       5.235000
# 75%    20050.750000    77.610000   336.000000     19.97750      13.900000
# max    93600.000000   100.000000   902.000000     88.32000     100.000000
#
#            Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  Calcium_(mg)  \
# count  8286.000000     8618.000000   7962.000000    6679.000000   8264.000000
# mean      1.816169       21.819062      2.189940       8.464779     76.556026
# ...

# %%
df.shape
# Out:
# (8618, 36)

# %%
df.dtypes
# Out:
# NDB_No               int64
# Shrt_Desc           object
# Water_(g)          float64
# Energ_Kcal           int64
# Protein_(g)        float64
# Lipid_Tot_(g)      float64
# Ash_(g)            float64
# Carbohydrt_(g)     float64
# Fiber_TD_(g)       float64
# Sugar_Tot_(g)      float64
# Calcium_(mg)       float64
# Iron_(mg)          float64
# Magnesium_(mg)     float64
# Phosphorus_(mg)    float64
# Potassium_(mg)     float64
# Sodium_(mg)        float64
# Zinc_(mg)          float64
# Copper_(mg)        float64
# Manganese_(mg)     float64
# Selenium_(mcg)     float64
# Vit_C_(mg)         float64
# Thiamin_(mg)       float64
# Riboflavin_(mg)    float64
# Niacin_(mg)        float64
# Vit_B6_(mg)        float64
# Vit_B12_(mcg)      float64
# Vit_A_IU           float64
# Vit_A_RAE          float64
# Vit_E_(mg)         float64
# Vit_D_mcg          float64
# Vit_D_IU           float64
# Vit_K_(mcg)        float64
# FA_Sat_(g)         float64
# FA_Mono_(g)        float64
# ...

# %%
col_names=df.columns

# %%
col_names
# Out:
# Index(['NDB_No', 'Shrt_Desc', 'Water_(g)', 'Energ_Kcal', 'Protein_(g)',
#        'Lipid_Tot_(g)', 'Ash_(g)', 'Carbohydrt_(g)', 'Fiber_TD_(g)',
#        'Sugar_Tot_(g)', 'Calcium_(mg)', 'Iron_(mg)', 'Magnesium_(mg)',
#        'Phosphorus_(mg)', 'Potassium_(mg)', 'Sodium_(mg)', 'Zinc_(mg)',
#        'Copper_(mg)', 'Manganese_(mg)', 'Selenium_(mcg)', 'Vit_C_(mg)',
#        'Thiamin_(mg)', 'Riboflavin_(mg)', 'Niacin_(mg)', 'Vit_B6_(mg)',
#        'Vit_B12_(mcg)', 'Vit_A_IU', 'Vit_A_RAE', 'Vit_E_(mg)', 'Vit_D_mcg',
#        'Vit_D_IU', 'Vit_K_(mcg)', 'FA_Sat_(g)', 'FA_Mono_(g)', 'FA_Poly_(g)',
#        'Cholestrl_(mg)'],
#       dtype='object')

# %%
fat_column=df[["FA_Sat_(g)","FA_Mono_(g)","FA_Poly_(g)"]]
fat_column.head()
# Out:
#    FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)
# 0      51.368       21.021        3.043
# 1      50.489       23.426        3.012
# 2      61.924       28.732        3.694
# 3      18.669        7.778        0.800
# 4      18.764        8.598        0.784

# %%
good_fat=df['FA_Mono_(g)'] + df['FA_Poly_(g)']

# %%
good_fat
# Out:
# 0       24.064
# 1       26.438
# 2       32.426
# 3        8.578
# 4        9.382
# 5        8.839
# 6        7.747
# 7        9.105
# 8        9.861
# 9        9.541
# 10      10.233
# 11       0.901
# 12       1.160
# 13       0.082
# 14       0.599
# 15       0.322
# 16      10.057
# 17       8.790
# 18       5.214
# 19      10.341
# 20       8.817
# 21       8.404
# 22      11.776
# 23       9.101
# 24       9.650
# 25       7.338
# 26       7.805
# 27       4.982
# 28       5.965
# 29       9.372
#          ...
# 8588     0.483
# 8589     0.069
# 8590     0.065
# 8591    11.365
# 8592     4.138
# 8593     7.657
# 8594     0.093
# 8595     1.531
# 8596     5.900
# 8597     5.353
# 8598    63.565
# 8599    81.066
# 8600     0.000
# 8601    10.644
# 8602     1.440
# 8603     1.285
# 8604     0.000
# 8605     0.009
# 8606     0.000
# 8607     0.010
# 8608     1.280
# 8609     0.082
# 8610     0.549
# 8611     0.966
# 8612     0.155
# 8613    14.530
# 8614     0.304
# ...

# %%
print(type(good_fat))
# Out:
# <class 'pandas.core.series.Series'>

# %%
food_descr=df["Shrt_Desc"]
food_descr
# Out:
# 0                                        BUTTER WITH SALT
# 1                                BUTTER WHIPPED WITH SALT
# 2                                    BUTTER OIL ANHYDROUS
# 3                                             CHEESE BLUE
# 4                                            CHEESE BRICK
# 5                                             CHEESE BRIE
# 6                                        CHEESE CAMEMBERT
# 7                                          CHEESE CARAWAY
# 8                                          CHEESE CHEDDAR
# 9                                         CHEESE CHESHIRE
# 10                                           CHEESE COLBY
# 11                    CHEESE COTTAGE CRMD LRG OR SML CURD
# 12                            CHEESE COTTAGE CRMD W/FRUIT
# 13       CHEESE COTTAGE NONFAT UNCRMD DRY LRG OR SML CURD
# 14                       CHEESE COTTAGE LOWFAT 2% MILKFAT
# 15                       CHEESE COTTAGE LOWFAT 1% MILKFAT
# ...

# %%
food_d=food_descr.tolist()
print(food_d)
# Out:
# ['BUTTER WITH SALT', 'BUTTER WHIPPED WITH SALT', 'BUTTER OIL ANHYDROUS', 'CHEESE BLUE', 'CHEESE BRICK', 'CHEESE BRIE', 'CHEESE CAMEMBERT', 'CHEESE CARAWAY', 'CHEESE CHEDDAR', 'CHEESE CHESHIRE', 'CHEESE COLBY', 'CHEESE COTTAGE CRMD LRG OR SML CURD', 'CHEESE COTTAGE CRMD W/FRUIT', 'CHEESE COTTAGE NONFAT UNCRMD DRY LRG OR SML CURD', 'CHEESE COTTAGE LOWFAT 2% MILKFAT', 'CHEESE COTTAGE LOWFAT 1% MILKFAT', 'CHEESE CREAM', 'CHEESE EDAM', 'CHEESE FETA', 'CHEESE FONTINA', 'CHEESE GJETOST', 'CHEESE GOUDA', 'CHEESE GRUYERE', 'CHEESE LIMBURGER', 'CHEESE MONTEREY', 'CHEESE MOZZARELLA WHL MILK', 'CHEESE MOZZARELLA WHL MILK LO MOIST', 'CHEESE MOZZARELLA PART SKIM MILK', 'CHEESE MOZZARELLA LO MOIST PART-SKIM', 'CHEESE MUENSTER', 'CHEESE NEUFCHATEL', 'CHEESE PARMESAN GRATED', 'CHEESE PARMESAN HARD', 'CHEESE PORT DE SALUT', 'CHEESE PROVOLONE', 'CHEESE RICOTTA WHOLE MILK', 'CHEESE RICOTTA PART SKIM MILK', 'CHEESE ROMANO', 'CHEESE ROQUEFORT', 'CHEESE SWISS', 'CHEESE TILSIT', 'CHEESE PAST PROCESS AMERICA
# ...

# %%
good_f=good_fat.tolist()
print(type(good_f))
print(good_f)
# Out:
# <class 'list'>
# ...

# %%
print("food with max good fat " + food_d[694] + "and value for it is " +"str(good_f[694])")
# Out:
# food with max good fat OIL CANOLAand value for it is str(good_f[694])

# %%
food_d[694]
# Out:
# 'OIL CANOLA'

# %%
good_f[694]
# Out:
# 91.418

# %%
min_value=None
min_index=0
for i,value in enumerate(good_f):
    if min_value is None or value<min_value:
        min_value=value
        min_index=i
print(min_value)
print(min_index)
print(food_d[59])
# Out:
# 0.0
# 59
# CHEESE AMERICAN NONFAT OR FAT FREE

# %% [markdown]
# # Thus the food with minimum good fat is CHEESE AMERICAN NONFAT OR FAT FREE with 0.0g good fat which shows it is not for health

# %%
count=0
low_good_fat=[]
for i,value in enumerate(good_f):
    if value == 0.0:
        count += 1
        low_good_fat.append(i)
    
print(count)
# Out:
# 253

# %%
print(low_good_fat)
# Out:
# [59, 112, 123, 124, 151, 156, 161, 189, 193, 207, 221, 222, 276, 277, 281, 282, 295, 363, 364, 370, 376, 377, 385, 386, 394, 407, 451, 452, 456, 457, 704, 1208, 1232, 1247, 1248, 1250, 1252, 1295, 1296, 1310, 1393, 1395, 1397, 1398, 1400, 1440, 1467, 1477, 1566, 1576, 1582, 2510, 4151, 4154, 4163, 4164, 4167, 4171, 4172, 4177, 4178, 4180, 4185, 4186, 4187, 4188, 4191, 4194, 4195, 4198, 4199, 4206, 4207, 4208, 4209, 4212, 4213, 4215, 4219, 4220, 4229, 4237, 4239, 4243, 4247, 4251, 4252, 4253, 4254, 4255, 4256, 4257, 4258, 4259, 4260, 4262, 4263, 4264, 4265, 4266, 4270, 4276, 4298, 4301, 4305, 4309, 4310, 4312, 4316, 4317, 4319, 4323, 4330, 4332, 4335, 4337, 4339, 4340, 4344, 4345, 4347, 4348, 4350, 4353, 4354, 4355, 4356, 4360, 4369, 4371, 4375, 4380, 4381, 4383, 4388, 4389, 4391, 4392, 4398, 4400, 4401, 4402, 4403, 4404, 4405, 4408, 4409, 4411, 4412, 4429, 4430, 4431, 4432, 4433, 4434, 4435, 4438, 4440, 4442, 4445, 4446, 4447, 4448, 4449, 4450, 4451, 5811, 5812, 5814, 5815, 5976, 608
# ...

# %%
for value in low_good_fat:
    print(food_d[value])
# Out:
# CHEESE AMERICAN NONFAT OR FAT FREE
# EGG WHITE RAW FRESH
# EGG WHITE DRIED FLAKES STABILIZED GLUCOSE RED
# EGG WHITE DRIED PDR STABILIZED GLUCOSE RED
# EGG WHITE DRIED
# SOUR CREAM FAT FREE
# YOGURT CHOC NONFAT MILK
# YOGURT CHOC NONFAT MILK FORT W/ VITAMIN D
# EGG SUB LIQ OR FRZ FAT FREE
# FAT FREE ICE CRM NO SUGAR ADDED FLAVORS OTHER THAN CHOC
# CHEESE CHEDDAR NONFAT OR FAT FREE
# CHEESE SWISS NONFAT OR FAT FREE
# SALT TABLE
# VINEGAR CIDER
# VANILLA EXTRACT IMITN NO ALCOHOL
# VINEGAR DISTILLED
# BABYFOOD JUC TREATS FRUIT MEDLEY TODD
# BABYFOOD FRUIT APPLSAUC JR
# BABYFOOD FRUIT APRICOT W/TAPIOCA STR
# BABYFOOD FRUIT APRICOT W/TAPIOCA JR
# BABYFOOD FRUIT PLUMS W/TAPIOCA WO/VIT C STR
# BABYFOOD FRUIT PLUMS W/TAPIOCA WO/VIT C JR
# BABYFOOD FRUIT APPLSAUC&CHERRIES STR
# BABYFOOD FRUIT APPLSAUC & CHERRIES JR
# BABYFOOD FRUIT BANANAS&PNAPPL W/TAPIOCA STR
# BABYFOOD JUC APPL&PLUM
# BABYFOOD DSSRT PEACH COBBLER STR
# BABYFOOD DSSRT PEACH COBBLER JR
# ...

# %%
# %time
df["Good_Fat_(g)"]= good_f
df["Good_Fat_(g)"]
# Out:
# Wall time: 0 ns
# 0       24.064
# 1       26.438
# 2       32.426
# 3        8.578
# 4        9.382
# 5        8.839
# 6        7.747
# 7        9.105
# 8        9.861
# 9        9.541
# 10      10.233
# 11       0.901
# 12       1.160
# 13       0.082
# 14       0.599
# 15       0.322
# 16      10.057
# 17       8.790
# 18       5.214
# 19      10.341
# 20       8.817
# 21       8.404
# 22      11.776
# 23       9.101
# 24       9.650
# 25       7.338
# 26       7.805
# 27       4.982
# 28       5.965
# 29       9.372
#          ...
# 8588     0.483
# 8589     0.069
# 8590     0.065
# 8591    11.365
# 8592     4.138
# 8593     7.657
# 8594     0.093
# 8595     1.531
# 8596     5.900
# 8597     5.353
# 8598    63.565
# 8599    81.066
# 8600     0.000
# 8601    10.644
# 8602     1.440
# 8603     1.285
# 8604     0.000
# 8605     0.009
# 8606     0.000
# 8607     0.010
# 8608     1.280
# 8609     0.082
# 8610     0.549
# 8611     0.966
# 8612     0.155
# 8613    14.530
# ...

# %%
#%lsmagic

# %%
sum_v=df['Good_Fat_(g)'].sum()
sum_v
# Out:
# 51193.375

# %%
import matplotlib.pyplot as plt

# %%
#plt.plot("Good_Fat_(g)","FA_Sat_(g)")

# %%
pvt=df.pivot_table(index="Good_Fat_(g)",values="FA_Sat_(g)")

pvt.head()
type(pvt)
pvt.index
pvt.loc[0.001]
pvt.shape
# Out:
# (5114, 1)

# %%
first_three_rows_cols=df.iloc[0:3,0:3]

# %%
first_three_rows_cols

# %%
loc_ana=df.loc[2:4,"Shrt_Desc"]
print(loc_ana.head())
col_ana=df["Shrt_Desc"]
col_ana.head()

# %%
#df.sort_values("Good_Fat_(g)",inplace=True,ascending=False)

# %%
b=df["Good_Fat_(g)"]
b

# %%
for i in range(0,len(b)):
    print(b[i])

# %%
major=df[df["Good_Fat_(g)"]==11.766]
w=df["Good_Fat_(g)"]==10.233
type(w)

# %%
major

# %%
df.loc[9]["Shrt_Desc"]
